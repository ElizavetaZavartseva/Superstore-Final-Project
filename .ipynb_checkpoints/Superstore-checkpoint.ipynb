# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)

pd.set_option('display.max_colwidth', 1)
#to show all values in row

# %%
df_superstore = pd.read_csv('superstore.csv')
df_superstore
# Out:
#               Category         City        Country Customer.ID  \
# 0      Office Supplies  Los Angeles  United States  LS-172304
# 1      Office Supplies  Los Angeles  United States  MV-174854
# 2      Office Supplies  Los Angeles  United States  CS-121304
# 3      Office Supplies  Los Angeles  United States  CS-121304
# 4      Office Supplies  Los Angeles  United States  AP-109154
# ...                ...          ...            ...        ...
# 51285  Office Supplies  Los Angeles  United States  AM-103604
# 51286  Office Supplies  Los Angeles  United States  AM-103604
# 51287  Office Supplies  Los Angeles  United States  HR-147704
# 51288  Office Supplies  Los Angeles  United States  RM-196754
# 51289  Office Supplies  Los Angeles  United States  FH-143654
#
#           Customer.Name  Discount Market  记录数               Order.Date  \
# 0      Lycoris Saunders  0.0       US     1    2011-01-07 00:00:00.000
# 1      Mark Van Huff     0.0       US     1    2011-01-21 00:00:00.000
# 2      Chad Sievert      0.0       US     1    2011-08-05 00:00:00.000
# 3      Chad Sievert      0.0       US     1    2011-08-05 00:00:00.000
# 4      Arthur Prichep    0.0       US     1    2011-09-29 00:00:00.000
# ...               ...    ...       ..    ..                        ...
# 51285  Alice McCarthy    0.2       US     1    2014-12-03 00:00:00.000
# 51286  Alice McCarthy    0.2       US     1    2014-12-03 00:00:00.000
# 51287  Hallie Redmond    0.2       US     1    2014-12-18 00:00:00.000
# 51288  Robert Marley     0.2       US     1    2014-12-25 00:00:00.000
# 51289  Fred Hopkins      0.2       US     1    2014-12-26 00:00:00.000
#
#              Order.ID Order.Priority       Product.ID  \
# 0      CA-2011-130813  High           OFF-PA-10002005
# 1      CA-2011-148614  Medium         OFF-PA-10002893
# 2      CA-2011-118962  Medium         OFF-PA-10000659
# 3      CA-2011-118962  Medium         OFF-PA-10001144
# 4      CA-2011-146969  High           OFF-PA-10002105
# ...               ...   ...                       ...
# 51285  CA-2014-109701  High           OFF-BI-10000632
# 51286  CA-2014-109701  High           OFF-BI-10004187
# 51287  CA-2014-106964  Medium         OFF-BI-10000320
# 51288  CA-2014-145219  Critical       OFF-BI-10001670
# 51289  CA-2014-121398  Medium         OFF-BI-10001718
#
#                                                                      Product.Name  \
# 0      Xerox 225
# 1      Wirebound Service Call Books, 5 1/2" x 4"
# 2      Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6” x 11”
# 3      Xerox 1913
# 4      Xerox 223
# ...          ...
# 51285  Satellite Sectional Post Binders
# 51286  Staples
# 51287  GBC Plastic Binding Combs
# 51288  Vinyl Sectional Post Binders
# 51289  GBC DocuBind P50 Personal Binding Machine
#
#         Profit  Quantity Region  Row.ID  Sales      Segment  \
# 0      9.3312   3         West   36624   19     Consumer
# 1      9.2928   2         West   37033   19     Consumer
# 2      9.8418   3         West   31468   21     Consumer
# 3      53.2608  2         West   31469   111    Consumer
# 4      3.1104   1         West   32440   6      Consumer
# ...       ...  ..          ...     ...  ..           ...
# 51285  22.5732  2         West   33646   69     Corporate
# 51286  3.1584   6         West   33645   9      Corporate
# 51287  4.2804   2         West   32321   12     Home Office
# 51288  33.9300  3         West   35917   90     Home Office
# 51289  51.8238  3         West   37371   154    Corporate
#
#                      Ship.Date       Ship.Mode  Shipping.Cost       State  \
# 0      2011-01-09 00:00:00.000  Second Class    4.37           California
# 1      2011-01-26 00:00:00.000  Standard Class  0.94           California
# 2      2011-08-09 00:00:00.000  Standard Class  1.81           California
# 3      2011-08-09 00:00:00.000  Standard Class  4.59           California
# 4      2011-10-03 00:00:00.000  Standard Class  1.32           California
# ...                        ...             ...   ...                  ...
# 51285  2014-12-04 00:00:00.000  Same Day        5.15           California
# 51286  2014-12-04 00:00:00.000  Same Day        0.44           California
# 51287  2014-12-21 00:00:00.000  First Class     0.31           California
# 51288  2014-12-26 00:00:00.000  First Class     15.95          California
# 51289  2014-12-30 00:00:00.000  Standard Class  9.59           California
#
#       Sub.Category  Year        Market2  weeknum
# 0      Paper        2011  North America  2
# 1      Paper        2011  North America  4
# 2      Paper        2011  North America  32
# 3      Paper        2011  North America  32
# 4      Paper        2011  North America  40
# ...      ...         ...            ...  ..
# 51285  Binders      2014  North America  49
# 51286  Binders      2014  North America  49
# 51287  Binders      2014  North America  51
# 51288  Binders      2014  North America  52
# 51289  Binders      2014  North America  52
#
# [51290 rows x 27 columns]

# %% [markdown]
# # Data Cleaning

# %%
#Checking duplicated values

df_superstore.duplicated().sum()
# Out:
# 0

# %%
#Checking null values

df_superstore.isna().sum()
# Out:
# Category          0
# City              0
# Country           0
# Customer.ID       0
# Customer.Name     0
# Discount          0
# Market            0
# 记录数               0
# Order.Date        0
# Order.ID          0
# Order.Priority    0
# Product.ID        0
# Product.Name      0
# Profit            0
# Quantity          0
# Region            0
# Row.ID            0
# Sales             0
# Segment           0
# Ship.Date         0
# Ship.Mode         0
# Shipping.Cost     0
# State             0
# Sub.Category      0
# Year              0
# Market2           0
# weeknum           0
# dtype: int64

# %%
#Renaiming columns

df_superstore.columns = df_superstore.columns.str.lower()\
                                                    .str.replace(' ', '_')\
                                                    .str.replace('.', '_')\
                                                    .str.replace('order_id', 'order_number')
# Out:
# /var/folders/1_/fmystfg15lbf3t1n1mmy4psw0000gn/T/ipykernel_64323/2293939430.py:5: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   .str.replace('.', '_')\

# %%
#Removing some columns

df_superstore.drop(['记录数', 'year', 'market2', 'weeknum', 'row_id'], axis=1, inplace=True)
df_superstore.head(1)
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States  LS-172304   Lycoris Saunders
#
#    discount market               order_date    order_number order_priority  \
# 0  0.0       US     2011-01-07 00:00:00.000  CA-2011-130813  High
#
#         product_id product_name  profit  quantity region  sales   segment  \
# 0  OFF-PA-10002005  Xerox 225    9.3312  3         West   19     Consumer
#
#                  ship_date     ship_mode  shipping_cost       state  \
# 0  2011-01-09 00:00:00.000  Second Class  4.37           California
#
#   sub_category
# 0  Paper

# %% [markdown]
# ### < Convert object columns to datetime64

# %%
df_superstore.dtypes
# Out:
# category          object
# city              object
# country           object
# customer_id       object
# customer_name     object
# discount          float64
# market            object
# order_date        object
# order_number      object
# order_priority    object
# product_id        object
# product_name      object
# profit            float64
# quantity          int64
# region            object
# sales             int64
# segment           object
# ship_date         object
# ship_mode         object
# shipping_cost     float64
# state             object
# sub_category      object
# dtype: object

# %%
#Cleaning column "order_date"

df_superstore["order_date"] = df_superstore["order_date"].str.split().str[0]
df_superstore["order_date"] = pd.to_datetime(df_superstore["order_date"], format="%Y/%m/%d")

#To pull year from data: df_superstore['order_date'].dt.year

# %%
#Cleaning column "ship_date"

df_superstore["ship_date"] = df_superstore["ship_date"].str.split().str[0]
df_superstore["ship_date"] = pd.to_datetime(df_superstore["ship_date"], format="%Y/%m/%d")

df_superstore.head(1)
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States  LS-172304   Lycoris Saunders
#
#    discount market order_date    order_number order_priority       product_id  \
# 0  0.0       US    2011-01-07  CA-2011-130813  High           OFF-PA-10002005
#
#   product_name  profit  quantity region  sales   segment  ship_date  \
# 0  Xerox 225    9.3312  3         West   19     Consumer 2011-01-09
#
#       ship_mode  shipping_cost       state sub_category
# 0  Second Class  4.37           California  Paper

# %%
df_superstore.dtypes
# Out:
# category          object
# city              object
# country           object
# customer_id       object
# customer_name     object
# discount          float64
# market            object
# order_date        datetime64[ns]
# order_number      object
# order_priority    object
# product_id        object
# product_name      object
# profit            float64
# quantity          int64
# region            object
# sales             int64
# segment           object
# ship_date         datetime64[ns]
# ship_mode         object
# shipping_cost     float64
# state             object
# sub_category      object
# dtype: object

# %%
df_superstore.shape
# Out:
# (51290, 22)

# %% [markdown]
# ### Convert object columns to datetime64 >

# %%
df_superstore.loc[df_superstore['order_number'] == 'CA-2014-121398']
# Out:
#               category         city        country customer_id customer_name  \
# 344    Office Supplies  Los Angeles  United States  FH-143654   Fred Hopkins
# 51289  Office Supplies  Los Angeles  United States  FH-143654   Fred Hopkins
#
#        discount market order_date    order_number order_priority  \
# 344    0.0       US    2014-12-26  CA-2014-121398  Medium
# 51289  0.2       US    2014-12-26  CA-2014-121398  Medium
#
#             product_id  \
# 344    OFF-ST-10002756
# 51289  OFF-BI-10001718
#
#                                                            product_name  \
# 344    Tennsco Stur-D-Stor Boltless Shelving, 5 Shelves, 24" Deep, Sand
# 51289  GBC DocuBind P50 Personal Binding Machine
#
#         profit  quantity region  sales    segment  ship_date       ship_mode  \
# 344    2.7062   2         West   271    Corporate 2014-12-30  Standard Class
# 51289  51.8238  3         West   154    Corporate 2014-12-30  Standard Class
#
#        shipping_cost       state sub_category
# 344    16.73          California  Storage
# 51289  9.59           California  Binders

# %%
df_superstore.loc[df_superstore['order_number'] == 'CA-2014-109701']
# Out:
#               category         city        country customer_id  \
# 115    Office Supplies  Los Angeles  United States  AM-103604
# 179    Office Supplies  Los Angeles  United States  AM-103604
# 241    Office Supplies  Los Angeles  United States  AM-103604
# 51285  Office Supplies  Los Angeles  United States  AM-103604
# 51286  Office Supplies  Los Angeles  United States  AM-103604
#
#         customer_name  discount market order_date    order_number  \
# 115    Alice McCarthy  0.0       US    2014-12-03  CA-2014-109701
# 179    Alice McCarthy  0.0       US    2014-12-03  CA-2014-109701
# 241    Alice McCarthy  0.0       US    2014-12-03  CA-2014-109701
# 51285  Alice McCarthy  0.2       US    2014-12-03  CA-2014-109701
# 51286  Alice McCarthy  0.2       US    2014-12-03  CA-2014-109701
#
#       order_priority       product_id  \
# 115    High           OFF-PA-10003724
# 179    High           OFF-AR-10001868
# 241    High           OFF-AP-10002765
# 51285  High           OFF-BI-10000632
# 51286  High           OFF-BI-10004187
#
#                                              product_name   profit  quantity  \
# 115    Wirebound Message Book, 4 per Page                  5.3214   2
# 179    Prang Dustless Chalk Sticks                         5.0400   6
# 241    Fellowes Advanced Computer Series Surge Protectors  22.2516  3
# 51285  Satellite Sectional Post Binders                    22.5732  2
# 51286  Staples                                             3.1584   6
#
#       region  sales    segment  ship_date ship_mode  shipping_cost  \
# 115    West   11     Corporate 2014-12-04  Same Day  1.77
# 179    West   10     Corporate 2014-12-04  Same Day  0.23
# 241    West   79     Corporate 2014-12-04  Same Day  8.23
# 51285  West   69     Corporate 2014-12-04  Same Day  5.15
# 51286  West   9      Corporate 2014-12-04  Same Day  0.44
#
#             state sub_category
# 115    California  Paper
# 179    California  Art
# 241    California  Appliances
# 51285  California  Binders
# 51286  California  Binders

# %% [markdown]
# # < Creating new columns for creating DataBase

# %% [markdown]
# ### 'oreder_id'

# %%
df_superstore['cum_count'] = df_superstore.groupby('order_number').cumcount() + 1

# %%
df_superstore['order_id'] = df_superstore['order_number'] + '_' + df_superstore['cum_count'].astype(str)
df_superstore.head()
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States  LS-172304   Lycoris Saunders
# 1  Office Supplies  Los Angeles  United States  MV-174854   Mark Van Huff
# 2  Office Supplies  Los Angeles  United States  CS-121304   Chad Sievert
# 3  Office Supplies  Los Angeles  United States  CS-121304   Chad Sievert
# 4  Office Supplies  Los Angeles  United States  AP-109154   Arthur Prichep
#
#    discount market order_date    order_number order_priority       product_id  \
# 0  0.0       US    2011-01-07  CA-2011-130813  High           OFF-PA-10002005
# 1  0.0       US    2011-01-21  CA-2011-148614  Medium         OFF-PA-10002893
# 2  0.0       US    2011-08-05  CA-2011-118962  Medium         OFF-PA-10000659
# 3  0.0       US    2011-08-05  CA-2011-118962  Medium         OFF-PA-10001144
# 4  0.0       US    2011-09-29  CA-2011-146969  High           OFF-PA-10002105
#
#                                                                  product_name  \
# 0  Xerox 225
# 1  Wirebound Service Call Books, 5 1/2" x 4"
# 2  Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6” x 11”
# 3  Xerox 1913
# 4  Xerox 223
#
#     profit  quantity region  sales   segment  ship_date       ship_mode  \
# 0  9.3312   3         West   19     Consumer 2011-01-09  Second Class
# 1  9.2928   2         West   19     Consumer 2011-01-26  Standard Class
# 2  9.8418   3         West   21     Consumer 2011-08-09  Standard Class
# 3  53.2608  2         West   111    Consumer 2011-08-09  Standard Class
# 4  3.1104   1         West   6      Consumer 2011-10-03  Standard Class
#
#    shipping_cost       state sub_category  cum_count          order_id
# 0  4.37           California  Paper        1          CA-2011-130813_1
# 1  0.94           California  Paper        1          CA-2011-148614_1
# 2  1.81           California  Paper        1          CA-2011-118962_1
# 3  4.59           California  Paper        2          CA-2011-118962_2
# 4  1.32           California  Paper        1          CA-2011-146969_1

# %% [markdown]
# ### 'market_id'

# %%
df_market_ids = df_superstore[['market', 'country']]
df_market_ids = df_market_ids.drop_duplicates()
df_market_ids['country_number'] = df_market_ids.groupby(['market']).cumcount() + 1
df_market_ids
# Out:
#        market                           country  country_number
# 0      US      United States                     1
# 3129   EU      France                            1
# 3216   EU      Germany                           2
# 3217   LATAM   El Salvador                       1
# 3226   LATAM   Guatemala                         2
# 3228   EU      Austria                           3
# 3232   LATAM   Nicaragua                         3
# 3288   EU      Belgium                           4
# 3298   EU      Switzerland                       5
# 3316   EU      Italy                             6
# 3317   Africa  South Africa                      1
# 3318   APAC    India                             1
# 3319   APAC    Hong Kong                         2
# 3321   Africa  Democratic Republic of the Congo  2
# 3322   LATAM   Cuba                              4
# 3323   EU      United Kingdom                    7
# 3324   EU      Spain                             8
# 3327   EMEA    Russia                            1
# 3329   APAC    China                             3
# 3332   Africa  Niger                             3
# 3333   EMEA    Qatar                             2
# 3334   APAC    New Zealand                       4
# 3335   LATAM   Mexico                            5
# 3339   APAC    Malaysia                          5
# 3346   EMEA    Poland                            3
# 3350   Africa  Madagascar                        4
# 3351   EMEA    Iraq                              4
# 3354   LATAM   Brazil                            6
# 3358   LATAM   Colombia                          7
# 3368   EMEA    Saudi Arabia                      5
# 3370   Africa  Egypt                             5
# 3376   EMEA    Iran                              6
# 3378   EMEA    Ukraine                           7
# 3383   APAC    Japan                             6
# 3394   Africa  Morocco                           6
# 3403   Africa  Cameroon                          7
# 3409   LATAM   Chile                             8
# 3420   Africa  Ghana                             8
# 3423   LATAM   Trinidad and Tobago               9
# 3452   Canada  Canada                            1
# 3460   Africa  Chad                              9
# 3461   Africa  Kenya                             10
# 3467   APAC    Bangladesh                        7
# 3470   EMEA    Bulgaria                          8
# 3482   Africa  Djibouti                          11
# 3486   LATAM   Uruguay                           10
# 3493   APAC    Singapore                         8
# 3527   EMEA    Czech Republic                    9
# 3528   Africa  Zambia                            12
# 3538   LATAM   Bolivia                           11
# 3544   Africa  Angola                            13
# 3549   APAC    Australia                         9
# 3580   Africa  Tanzania                          14
# 3621   EU      Norway                            9
# 3645   Africa  Sierra Leone                      15
# 3688   EMEA    Hungary                           10
# 3717   LATAM   Ecuador                           12
# 3751   EU      Finland                           10
# 3762   APAC    Afghanistan                       10
# 3816   EMEA    Uzbekistan                        11
# 3818   EMEA    Romania                           12
# 3820   EMEA    Kyrgyzstan                        13
# 3837   EMEA    Austria                           14
# 3841   EMEA    Belarus                           15
# 3850   EMEA    Mongolia                          16
# 3853   EMEA    Georgia                           17
# 3856   EMEA    Syria                             18
# 3862   EMEA    Croatia                           19
# 3868   EMEA    Israel                            20
# 3886   Africa  Liberia                           16
# 3892   Africa  Guinea-Bissau                     17
# 3899   Africa  Somalia                           18
# 3907   Africa  Senegal                           19
# 3917   Africa  Tunisia                           20
# 3921   Africa  Mali                              21
# 3925   Africa  Algeria                           22
# 3955   Africa  Benin                             23
# 3960   Africa  Ethiopia                          24
# 3965   Africa  Libya                             25
# 3974   Africa  Mozambique                        26
# 4002   LATAM   Guadeloupe                        13
# 4018   EMEA    Jordan                            21
# 4069   Africa  Togo                              27
# 4279   Africa  Cote d'Ivoire                     28
# 4326   APAC    Taiwan                            11
# 4388   LATAM   Jamaica                           14
# 4426   APAC    Cambodia                          12
# 4627   EMEA    Azerbaijan                        22
# 4631   Africa  Lesotho                           29
# 4778   EMEA    Bahrain                           23
# 4811   EMEA    Montenegro                        24
# 5025   EMEA    Moldova                           25
# 5062   Africa  Rwanda                            30
# 5223   APAC    Nepal                             13
# 5288   LATAM   Martinique                        15
# 5435   EMEA    Estonia                           26
# 5449   EMEA    Albania                           27
# 5451   EMEA    Slovakia                          28
# 5588   Africa  Sudan                             31
# 5611   Africa  Guinea                            32
# 5698   Africa  Republic of the Congo             33
# 5740   Africa  Namibia                           34
# 5838   APAC    Sri Lanka                         14
# 5965   Africa  Central African Republic          35
# 6091   Africa  Eritrea                           36
# 6273   EMEA    Lebanon                           29
# 6295   EMEA    Bosnia and Herzegovina            30
# 6341   LATAM   Barbados                          16
# 7113   LATAM   Paraguay                          17
# 8012   Africa  Mauritania                        37
# 9061   Africa  Swaziland                         38
# 9463   Africa  Gabon                             39
# 9626   EMEA    Armenia                           31
# 9854   EMEA    Slovenia                          32
# 13204  EMEA    Macedonia                         33
# 15987  Africa  Equatorial Guinea                 40
# 20668  Africa  South Sudan                       41
# 22329  Africa  Burundi                           42
# 29302  EMEA    Turkey                            34
# 29484  Africa  Nigeria                           43
# 29611  EMEA    Turkmenistan                      35
# 29614  EMEA    Kazakhstan                        36
# 29621  EMEA    Lithuania                         37
# 29630  EMEA    Yemen                             38
# 29631  Africa  Uganda                            44
# 29633  Africa  Zimbabwe                          45
# 29648  EMEA    United Arab Emirates              39
# 29666  EU      Sweden                            11
# 29668  EU      Denmark                           12
# 29669  EU      Ireland                           13
# 29725  EU      Portugal                          14
# 29829  EU      Netherlands                       15
# 30074  APAC    South Korea                       15
# 30075  APAC    Pakistan                          16
# 30092  APAC    Papua New Guinea                  17
# 30232  APAC    Thailand                          18
# 30233  APAC    Myanmar (Burma)                   19
# 30235  APAC    Vietnam                           20
# 30242  APAC    Philippines                       21
# 30452  APAC    Indonesia                         22
# 30781  LATAM   Dominican Republic                18
# 30891  LATAM   Haiti                             19
# 30894  LATAM   Panama                            20
# 30898  LATAM   Honduras                          21
# 30899  LATAM   Argentina                         22
# 30904  LATAM   Peru                              23
# 30913  LATAM   Venezuela                         24
# 40306  EMEA    Tajikistan                        40
# 40590  APAC    Mongolia                          23

# %%
df_superstore = pd.merge(df_superstore, df_market_ids, on=['market', 'country'], how='left')
df_superstore['market_id'] = df_superstore['market'] + '-' + df_superstore['country_number'].astype(str)
df_superstore.head(1)
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States  LS-172304   Lycoris Saunders
#
#    discount market order_date    order_number order_priority       product_id  \
# 0  0.0       US    2011-01-07  CA-2011-130813  High           OFF-PA-10002005
#
#   product_name  profit  quantity region  sales   segment  ship_date  \
# 0  Xerox 225    9.3312  3         West   19     Consumer 2011-01-09
#
#       ship_mode  shipping_cost       state sub_category  cum_count  \
# 0  Second Class  4.37           California  Paper        1
#
#            order_id  country_number market_id
# 0  CA-2011-130813_1  1               US-1

# %%
df_superstore.drop(['cum_count', 'country_number'], axis=1, inplace=True)
df_superstore.head(1)
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States  LS-172304   Lycoris Saunders
#
#    discount market order_date    order_number order_priority       product_id  \
# 0  0.0       US    2011-01-07  CA-2011-130813  High           OFF-PA-10002005
#
#   product_name  profit  quantity region  sales   segment  ship_date  \
# 0  Xerox 225    9.3312  3         West   19     Consumer 2011-01-09
#
#       ship_mode  shipping_cost       state sub_category          order_id  \
# 0  Second Class  4.37           California  Paper        CA-2011-130813_1
#
#   market_id
# 0  US-1

# %%
df_superstore.nunique()
# Out:
# category          3
# city              3636
# country           147
# customer_id       4873
# customer_name     795
# discount          27
# market            7
# order_date        1430
# order_number      25035
# order_priority    4
# product_id        10292
# product_name      3788
# profit            24575
# quantity          14
# region            13
# sales             2246
# segment           3
# ship_date         1464
# ship_mode         4
# shipping_cost     16877
# state             1094
# sub_category      17
# order_id          51290
# market_id         149
# dtype: int64

# %% [markdown]
# # Creating new columns for creating DataBase >

# %% [markdown]
# # < Creating tables for DataBase

# %% [markdown]
# ### < Table: customers

# %%
df_customers = df_superstore[['customer_id', 'customer_name', 'segment']]
df_customers.shape
# Out:
# (51290, 3)

# %%
df_customers.duplicated().sum()
# Out:
# 46417

# %%
df_customers.drop_duplicates(inplace=True)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df_customers
# Out:
#       customer_id      customer_name      segment
# 0      LS-172304   Lycoris Saunders   Consumer
# 1      MV-174854   Mark Van Huff      Consumer
# 2      CS-121304   Chad Sievert       Consumer
# 4      AP-109154   Arthur Prichep     Consumer
# 5      JF-154904   Jeremy Farry       Consumer
# ...          ...            ...            ...
# 49147  RE-194054   Ricardo Emerson    Consumer
# 49573  PH-187904   Patricia Hirasaki  Home Office
# 49632  JR-157004   Jocasta Rupert     Consumer
# 49857  CJ-118754   Carl Jackson       Corporate
# 51080  AO-108104   Anthony O'Donnell  Corporate
#
# [4873 rows x 3 columns]

# %%
df_customers.loc[df_customers['customer_name'] == 'Arthur Prichep']
# Out:
#       customer_id   customer_name   segment
# 4      AP-109154   Arthur Prichep  Consumer
# 6265   AP-109153   Arthur Prichep  Consumer
# 6509   AP-109151   Arthur Prichep  Consumer
# 7400   AP-9151     Arthur Prichep  Consumer
# 9031   AP-9152     Arthur Prichep  Consumer
# 18274  AP-109152   Arthur Prichep  Consumer

# %%
df_customers.duplicated(subset='customer_id').sum()
# 23875  EG-2013-2420_3     Africa-5
# 24018  EG-2013-2420_4     Africa-5
# 24111  EG-2013-2420_5     Africa-5
# 25440  IN-2014-46875_1    APAC-1
# 25460  IN-2014-18532_1    APAC-1
# 25532  IN-2012-68911_3    APAC-3
# 25577  IN-2014-50473_2    APAC-3
# 26032  SU-2012-2020_5     Africa-31
# 26125  MD-2014-4350_3     EMEA-25
# 26413  IN-2014-50473_3    APAC-3
# 27110  MX-2014-108973_1   LATAM-3
# 27163  MX-2012-124765_3   LATAM-5
# 28080  CA-2013-168893_4   US-1
# 28081  CA-2013-168893_5   US-1
# 28318  CA-2013-128412_4   US-1
# 28892  CA-2011-146969_4   US-1
# 33172  IN-2014-17972_1    APAC-22
# 33223  IN-2014-17972_2    APAC-22
# 34267  IN-2014-17972_3    APAC-22
# 40463  IN-2012-81623_1    APAC-4
# 40501  IT-2013-2076787_2  EU-6
# 40988  MX-2012-112466_1   LATAM-5
# 41458  US-2012-114860_1   LATAM-6
# 41581  MX-2012-162915_1   LATAM-18
# 41582  MX-2012-162915_2   LATAM-18
# 41812  TU-2012-90_1       EMEA-34
# 43213  IT-2014-4533109_1  EU-1
# 43400  ES-2014-1436831_1  EU-1
# 46019  IN-2012-36655_1    APAC-9
# 46020  IN-2012-36655_2    APAC-9
# 47418  US-2014-132059_1   US-1
# 48269  CA-2013-128412_5   US-1
# 48428  US-2014-132059_2   US-1
# 48439  CA-2011-124737_1   US-1
# 48440  CA-2011-124737_2   US-1
# 48441  CA-2011-124737_3   US-1
# 48442  CA-2011-124737_4   US-1
# 48443  CA-2011-124737_5   US-1
# 48444  CA-2011-124737_6   US-1
# 49569  CA-2014-146136_1   US-1
# 51033  CA-2011-146969_5   US-1
# 51039  CA-2011-105270_2   US-1

# %% [markdown]
# ### Table: customers >

# %% [markdown]
# ### < Table: products

# %%
df_products = df_superstore[['product_id', 'product_name', 'category', 'sub_category']]
df_products.shape
# Out:
# (51290, 4)

# %%
df_products.head()
# Out:
#         product_id  \
# 0  OFF-PA-10002005
# 1  OFF-PA-10002893
# 2  OFF-PA-10000659
# 3  OFF-PA-10001144
# 4  OFF-PA-10002105
#
#                                                                  product_name  \
# 0  Xerox 225
# 1  Wirebound Service Call Books, 5 1/2" x 4"
# 2  Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6” x 11”
# 3  Xerox 1913
# 4  Xerox 223
#
#           category sub_category
# 0  Office Supplies  Paper
# 1  Office Supplies  Paper
# 2  Office Supplies  Paper
# 3  Office Supplies  Paper
# 4  Office Supplies  Paper

# %%
df_products.drop_duplicates(inplace=True)
df_products.shape
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# (10768, 4)

# %%
df_products.duplicated(subset='product_id').sum()
# Out:
# 476

# %%
count_df = df_products['product_id'].value_counts().reset_index()
count_df = count_df.rename(columns={'index': 'product_id', 'product_id': 'counts'})
count_df
# Out:
#             product_id  counts
# 0      OFF-PA-10004673  4
# 1      OFF-PA-10000357  3
# 2      OFF-BI-10004632  3
# 3      OFF-BI-10002799  3
# 4      OFF-BI-10004654  3
# ...                ... ..
# 10287  TEC-PH-10000486  1
# 10288  OFF-AR-10002671  1
# 10289  OFF-EN-10003068  1
# 10290  OFF-AP-10000326  1
# 10291  TEC-MA-10001031  1
#
# [10292 rows x 2 columns]

# %%
df_products = pd.merge(df_products, count_df, on='product_id', how='left')
df_products
# Out:
#             product_id  \
# 0      OFF-PA-10002005
# 1      OFF-PA-10002893
# 2      OFF-PA-10000659
# 3      OFF-PA-10001144
# 4      OFF-PA-10002105
# ...                ...
# 10763  TEC-PH-10001949
# 10764  TEC-MA-10003246
# 10765  TEC-MA-10003329
# 10766  FUR-TA-10001691
# 10767  TEC-MA-10001031
#
#                                                                      product_name  \
# 0      Xerox 225
# 1      Wirebound Service Call Books, 5 1/2" x 4"
# 2      Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6” x 11”
# 3      Xerox 1913
# 4      Xerox 223
# ...          ...
# 10763  Cisco SPA 501G IP Phone
# 10764  Hewlett-Packard Deskjet D4360 Printer
# 10765  Vtech AT&T CL2940 Corded Speakerphone, Black
# 10766  Barricks Non-Folding Utility Table with Steel Legs, Laminate Tops
# 10767  Socket Bluetooth Cordless Hand Scanner (CHS)
#
#               category sub_category  counts
# 0      Office Supplies  Paper        1
# 1      Office Supplies  Paper        1
# 2      Office Supplies  Paper        2
# 3      Office Supplies  Paper        1
# 4      Office Supplies  Paper        1
# ...                ...    ...       ..
# 10763  Technology       Phones       1
# 10764  Technology       Machines     1
# 10765  Technology       Machines     1
# 10766  Furniture        Tables       1
# 10767  Technology       Machines     1
#
# [10768 rows x 5 columns]

# %%
df_products.loc[df_products['counts'] > 3]
# Out:
#            product_id                     product_name         category  \
# 2851  OFF-PA-10004673  Enermax Message Books, 8.5 x 11  Office Supplies
# 2999  OFF-PA-10004673  Eaton Note Cards, Multicolor     Office Supplies
# 5126  OFF-PA-10004673  Green Bar Memo Slips, Recycled   Office Supplies
# 9728  OFF-PA-10004673  Xerox Message Books, Multicolor  Office Supplies
#
#      sub_category  counts
# 2851  Paper        4
# 2999  Paper        4
# 5126  Paper        4
# 9728  Paper        4

# %%
df_products.loc[df_products['product_id'] == 'OFF-PA-10000659']
# Out:
#          product_id  \
# 2   OFF-PA-10000659
# 70  OFF-PA-10000659
#
#                                                                   product_name  \
# 2   Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6” x 11”
# 70  TOPS Carbonless Receipt Book, Four 2-3/4 x 7-1/4 Money Receipts per Page
#
#            category sub_category  counts
# 2   Office Supplies  Paper        2
# 70  Office Supplies  Paper        2

# %%
# df_products.drop_duplicates(subset='product_id', inplace=True)

# %%
# df_products.duplicated(subset='product_id').sum()

# %% [markdown]
# ### Table: products >

# %% [markdown]
# ### < Table: orders

# %%
df_superstore.head(1)
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States  LS-172304   Lycoris Saunders
#
#    discount market order_date    order_number order_priority       product_id  \
# 0  0.0       US    2011-01-07  CA-2011-130813  High           OFF-PA-10002005
#
#   product_name  profit  quantity region  sales   segment  ship_date  \
# 0  Xerox 225    9.3312  3         West   19     Consumer 2011-01-09
#
#       ship_mode  shipping_cost       state sub_category          order_id  \
# 0  Second Class  4.37           California  Paper        CA-2011-130813_1
#
#   market_id
# 0  US-1

# %%
df_orders = df_superstore[['order_id', \
                           'order_number', \
                           'order_date', \
                           'order_priority', \
                           'product_id', \
                           'quantity', \
                           'customer_id', \
                           'city', \
                           'region', \
                           'market_id']]

# %%
df_orders
# Out:
#                order_id    order_number order_date order_priority  \
# 0      CA-2011-130813_1  CA-2011-130813 2011-01-07  High
# 1      CA-2011-148614_1  CA-2011-148614 2011-01-21  Medium
# 2      CA-2011-118962_1  CA-2011-118962 2011-08-05  Medium
# 3      CA-2011-118962_2  CA-2011-118962 2011-08-05  Medium
# 4      CA-2011-146969_1  CA-2011-146969 2011-09-29  High
# ...                 ...             ...        ...   ...
# 51285  CA-2014-109701_4  CA-2014-109701 2014-12-03  High
# 51286  CA-2014-109701_5  CA-2014-109701 2014-12-03  High
# 51287  CA-2014-106964_1  CA-2014-106964 2014-12-18  Medium
# 51288  CA-2014-145219_2  CA-2014-145219 2014-12-25  Critical
# 51289  CA-2014-121398_2  CA-2014-121398 2014-12-26  Medium
#
#             product_id  quantity customer_id         city region market_id
# 0      OFF-PA-10002005  3         LS-172304   Los Angeles  West   US-1
# 1      OFF-PA-10002893  2         MV-174854   Los Angeles  West   US-1
# 2      OFF-PA-10000659  3         CS-121304   Los Angeles  West   US-1
# 3      OFF-PA-10001144  2         CS-121304   Los Angeles  West   US-1
# 4      OFF-PA-10002105  1         AP-109154   Los Angeles  West   US-1
# ...                ... ..               ...           ...   ...    ...
# 51285  OFF-BI-10000632  2         AM-103604   Los Angeles  West   US-1
# 51286  OFF-BI-10004187  6         AM-103604   Los Angeles  West   US-1
# 51287  OFF-BI-10000320  2         HR-147704   Los Angeles  West   US-1
# 51288  OFF-BI-10001670  3         RM-196754   Los Angeles  West   US-1
# 51289  OFF-BI-10001718  3         FH-143654   Los Angeles  West   US-1
#
# [51290 rows x 10 columns]

# %%
df_orders.duplicated().sum()
# Out:
# 0

# %%
df_orders.loc[df_orders['order_number'] == 'CA-2014-121398']
# Out:
#                order_id    order_number order_date order_priority  \
# 344    CA-2014-121398_1  CA-2014-121398 2014-12-26  Medium
# 51289  CA-2014-121398_2  CA-2014-121398 2014-12-26  Medium
#
#             product_id  quantity customer_id         city region market_id
# 344    OFF-ST-10002756  2         FH-143654   Los Angeles  West   US-1
# 51289  OFF-BI-10001718  3         FH-143654   Los Angeles  West   US-1

# %%
df_superstore.loc[df_superstore['order_number'] == 'CA-2014-121398']
# Out:
#               category         city        country customer_id customer_name  \
# 344    Office Supplies  Los Angeles  United States  FH-143654   Fred Hopkins
# 51289  Office Supplies  Los Angeles  United States  FH-143654   Fred Hopkins
#
#        discount market order_date    order_number order_priority  \
# 344    0.0       US    2014-12-26  CA-2014-121398  Medium
# 51289  0.2       US    2014-12-26  CA-2014-121398  Medium
#
#             product_id  \
# 344    OFF-ST-10002756
# 51289  OFF-BI-10001718
#
#                                                            product_name  \
# 344    Tennsco Stur-D-Stor Boltless Shelving, 5 Shelves, 24" Deep, Sand
# 51289  GBC DocuBind P50 Personal Binding Machine
#
#         profit  quantity region  sales    segment  ship_date       ship_mode  \
# 344    2.7062   2         West   271    Corporate 2014-12-30  Standard Class
# 51289  51.8238  3         West   154    Corporate 2014-12-30  Standard Class
#
#        shipping_cost       state sub_category          order_id market_id
# 344    16.73          California  Storage      CA-2014-121398_1  US-1
# 51289  9.59           California  Binders      CA-2014-121398_2  US-1

# %% [markdown]
# ### Table: orders >

# %% [markdown]
# ### < Table: markets

# %%
df_superstore.head(1)
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States  LS-172304   Lycoris Saunders
#
#    discount market order_date    order_number order_priority       product_id  \
# 0  0.0       US    2011-01-07  CA-2011-130813  High           OFF-PA-10002005
#
#   product_name  profit  quantity region  sales   segment  ship_date  \
# 0  Xerox 225    9.3312  3         West   19     Consumer 2011-01-09
#
#       ship_mode  shipping_cost       state sub_category          order_id  \
# 0  Second Class  4.37           California  Paper        CA-2011-130813_1
#
#   market_id
# 0  US-1

# %%
df_markets = df_superstore[['market_id', 'market', 'country']]
df_markets.drop_duplicates(inplace=True)
df_markets
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#        market_id  market                           country
# 0      US-1       US      United States
# 3129   EU-1       EU      France
# 3216   EU-2       EU      Germany
# 3217   LATAM-1    LATAM   El Salvador
# 3226   LATAM-2    LATAM   Guatemala
# 3228   EU-3       EU      Austria
# 3232   LATAM-3    LATAM   Nicaragua
# 3288   EU-4       EU      Belgium
# 3298   EU-5       EU      Switzerland
# 3316   EU-6       EU      Italy
# 3317   Africa-1   Africa  South Africa
# 3318   APAC-1     APAC    India
# 3319   APAC-2     APAC    Hong Kong
# 3321   Africa-2   Africa  Democratic Republic of the Congo
# 3322   LATAM-4    LATAM   Cuba
# 3323   EU-7       EU      United Kingdom
# 3324   EU-8       EU      Spain
# 3327   EMEA-1     EMEA    Russia
# 3329   APAC-3     APAC    China
# 3332   Africa-3   Africa  Niger
# 3333   EMEA-2     EMEA    Qatar
# 3334   APAC-4     APAC    New Zealand
# 3335   LATAM-5    LATAM   Mexico
# 3339   APAC-5     APAC    Malaysia
# 3346   EMEA-3     EMEA    Poland
# 3350   Africa-4   Africa  Madagascar
# 3351   EMEA-4     EMEA    Iraq
# 3354   LATAM-6    LATAM   Brazil
# 3358   LATAM-7    LATAM   Colombia
# 3368   EMEA-5     EMEA    Saudi Arabia
# 3370   Africa-5   Africa  Egypt
# 3376   EMEA-6     EMEA    Iran
# 3378   EMEA-7     EMEA    Ukraine
# 3383   APAC-6     APAC    Japan
# 3394   Africa-6   Africa  Morocco
# 3403   Africa-7   Africa  Cameroon
# 3409   LATAM-8    LATAM   Chile
# 3420   Africa-8   Africa  Ghana
# 3423   LATAM-9    LATAM   Trinidad and Tobago
# 3452   Canada-1   Canada  Canada
# 3460   Africa-9   Africa  Chad
# 3461   Africa-10  Africa  Kenya
# 3467   APAC-7     APAC    Bangladesh
# 3470   EMEA-8     EMEA    Bulgaria
# 3482   Africa-11  Africa  Djibouti
# 15987  Africa-40  Africa  Equatorial Guinea
# 20668  Africa-41  Africa  South Sudan
# 22329  Africa-42  Africa  Burundi
# 29302  EMEA-34    EMEA    Turkey
# 29484  Africa-43  Africa  Nigeria
# 29611  EMEA-35    EMEA    Turkmenistan
# 29614  EMEA-36    EMEA    Kazakhstan
# 29621  EMEA-37    EMEA    Lithuania
# 29630  EMEA-38    EMEA    Yemen
# 29631  Africa-44  Africa  Uganda
# 29633  Africa-45  Africa  Zimbabwe
# 29648  EMEA-39    EMEA    United Arab Emirates
# 29666  EU-11      EU      Sweden
# 29668  EU-12      EU      Denmark
# 29669  EU-13      EU      Ireland
# 29725  EU-14      EU      Portugal
# 29829  EU-15      EU      Netherlands
# 30074  APAC-15    APAC    South Korea
# 30075  APAC-16    APAC    Pakistan
# 30092  APAC-17    APAC    Papua New Guinea
# 30232  APAC-18    APAC    Thailand
# 30233  APAC-19    APAC    Myanmar (Burma)
# 30235  APAC-20    APAC    Vietnam
# 30242  APAC-21    APAC    Philippines
# 30452  APAC-22    APAC    Indonesia
# 30781  LATAM-18   LATAM   Dominican Republic
# 30891  LATAM-19   LATAM   Haiti
# 30894  LATAM-20   LATAM   Panama
# 30898  LATAM-21   LATAM   Honduras
# 30899  LATAM-22   LATAM   Argentina
# 30904  LATAM-23   LATAM   Peru
# 30913  LATAM-24   LATAM   Venezuela
# 40306  EMEA-40    EMEA    Tajikistan
# 40590  APAC-23    APAC    Mongolia

# %%
df_markets.shape
# Out:
# (149, 3)

# %%
df_markets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 0 to 40590
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   market_id  149 non-null    object
#  1   market     149 non-null    object
#  2   country    149 non-null    object
# dtypes: object(3)
# memory usage: 4.7+ KB

# %% [markdown]
# ### Table: markets >

# %% [markdown]
# ### < Table: shipments

# %%
df_superstore.head(1)
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States  LS-172304   Lycoris Saunders
#
#    discount market order_date    order_number order_priority       product_id  \
# 0  0.0       US    2011-01-07  CA-2011-130813  High           OFF-PA-10002005
#
#   product_name  profit  quantity region  sales   segment  ship_date  \
# 0  Xerox 225    9.3312  3         West   19     Consumer 2011-01-09
#
#       ship_mode  shipping_cost       state sub_category          order_id  \
# 0  Second Class  4.37           California  Paper        CA-2011-130813_1
#
#   market_id
# 0  US-1

# %%
df_shipments = df_superstore[['order_id', 'ship_date', 'ship_mode', 'shipping_cost', 'state']]
df_shipments.duplicated().sum()
# Out:
# 0

# %%
df_shipments.head()
# Out:
#            order_id  ship_date       ship_mode  shipping_cost       state
# 0  CA-2011-130813_1 2011-01-09  Second Class    4.37           California
# 1  CA-2011-148614_1 2011-01-26  Standard Class  0.94           California
# 2  CA-2011-118962_1 2011-08-09  Standard Class  1.81           California
# 3  CA-2011-118962_2 2011-08-09  Standard Class  4.59           California
# 4  CA-2011-146969_1 2011-10-03  Standard Class  1.32           California

# %%
df_shipments.shape
# Out:
# (51290, 5)

# %% [markdown]
# ### Table: shipments >

# %% [markdown]
# ### < Table: payments

# %%
df_superstore.head(1)
# Out:
#           category         city        country customer_id     customer_name  \
# 0  Office Supplies  Los Angeles  United States  LS-172304   Lycoris Saunders
#
#    discount market order_date    order_number order_priority       product_id  \
# 0  0.0       US    2011-01-07  CA-2011-130813  High           OFF-PA-10002005
#
#   product_name  profit  quantity region  sales   segment  ship_date  \
# 0  Xerox 225    9.3312  3         West   19     Consumer 2011-01-09
#
#       ship_mode  shipping_cost       state sub_category          order_id  \
# 0  Second Class  4.37           California  Paper        CA-2011-130813_1
#
#   market_id
# 0  US-1

# %%
df_shipments = df_superstore[['order_id', 'sales', 'profit', 'discount']]
df_shipments.duplicated().sum()
# Out:
# 0

# %%
df_shipments.head()
# Out:
#            order_id  sales   profit  discount
# 0  CA-2011-130813_1  19     9.3312   0.0
# 1  CA-2011-148614_1  19     9.2928   0.0
# 2  CA-2011-118962_1  21     9.8418   0.0
# 3  CA-2011-118962_2  111    53.2608  0.0
# 4  CA-2011-146969_1  6      3.1104   0.0

# %%
df_shipments.shape
# Out:
# (51290, 4)

# %% [markdown]
# ### Table: payments >

# %% [markdown]
# # Creating tables for DataBase >

# %% [markdown]
# # MySQL: creating tables and inserting data

# %%
import mysql.connector

# %% [markdown]
# ### < Table: customers

# %%
def SQL_INSERT_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET):
    sql_texts = []
    for index, row in SOURCE.iterrows():       
        sql_texts.append('INSERT INTO '+TARGET+' ('+ str(', '.join(SOURCE.columns))+ ') VALUES '+ str(tuple(row.values)))        
    return sql_texts

def SQL_CREATE_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET):
    # SQL_CREATE_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET)
    # SOURCE: source dataframe
    # TARGET: target table to be created in database

    sql_text = pd.io.sql.get_schema(SOURCE.reset_index(), TARGET)   
    return sql_text

user = 'root'
password = 'Qwerty123'
host = 'localhost'
database = 'superstore_db'

db = mysql.connector.connect(
    user=user,
    password=password,
    host=host,
    database=database
)

# from sqlalchemy import create_engine
# engine = create_engine(f"mysql://root:Qwerty123@localhost/youtube_db")

insert_statements_list = SQL_INSERT_STATEMENT_FROM_DATAFRAME(df_customers, "customers")
text_query = SQL_CREATE_STATEMENT_FROM_DATAFRAME(df_customers, "customers")

# print(text_query)


sql = '''
        SET FOREIGN_KEY_CHECKS = 0;
        DROP TABLE IF EXISTS `customers`;
        CREATE TABLE `customers` (
          `customer_id` varchar(45) NOT NULL,
          `customer_name` varchar(45) DEFAULT NULL,
          `segment` varchar(45) DEFAULT NULL,
          PRIMARY KEY (`customer_id`)
        ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb3;
        ''' + "; ".join(insert_statements_list)

with db.cursor(buffered=True, dictionary=True) as c: 
    executables = c.execute(sql, multi=True)
    _ = [item for item in executables]
    db.commit() 
print("cool!")
# Out:
# cool!

# %% [markdown]
# ### Table: customers >

# %% [markdown]
# ### < Table: products

# %%
def SQL_INSERT_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET):
    sql_texts = []
    for index, row in SOURCE.iterrows():       
        sql_texts.append('INSERT INTO '+TARGET+' ('+ str(', '.join(SOURCE.columns))+ ') VALUES '+ str(tuple(row.values)))        
    return sql_texts

def SQL_CREATE_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET):
    # SQL_CREATE_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET)
    # SOURCE: source dataframe
    # TARGET: target table to be created in database

    sql_text = pd.io.sql.get_schema(SOURCE.reset_index(), TARGET)   
    return sql_text

user = 'root'
password = 'Qwerty123'
host = 'localhost'
database = 'superstore_db'

db = mysql.connector.connect(
    user=user,
    password=password,
    host=host,
    database=database
)

insert_statements_list = SQL_INSERT_STATEMENT_FROM_DATAFRAME(df_products, "products")
text_query = SQL_CREATE_STATEMENT_FROM_DATAFRAME(df_products, "products")

insert_statements_list = insert_statements_list[:1000:]

print(text_query)
print(len(insert_statements_list))

# from sqlalchemy import create_engine
# engine = create_engine(f"mysql://root:Qwerty123@localhost/youtube_db")
# Out:
# CREATE TABLE "products" (
# "index" INTEGER,
#   "product_id" TEXT,
#   "product_name" TEXT,
#   "category" TEXT,
#   "sub_category" TEXT,
#   "counts" INTEGER
# )
# 1000

# %%
sql = '''

        DROP TABLE IF EXISTS `products`;
        CREATE TABLE `products` (
          `product_id` varchar(45) NOT NULL,
          `product_name` varchar(255) DEFAULT NULL,
          `category` varchar(45) DEFAULT NULL,
          `sub_category` varchar(45) DEFAULT NULL,
          `counts` INT DEFAULT NULL,
          PRIMARY KEY (`product_id`)
        ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb3;
        ''' + "; ".join(insert_statements_list)

with db.cursor(buffered=True, dictionary=True) as c: 
    print('qqq')
    executables = c.execute(sql, multi=True)
    _ = [item for item in executables]
    db.commit() 

print("cool!")
# Out:
# qqq
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# Cell In[1364], line 17
#      15     print('qqq')
#      16     executables = c.execute(sql, multi=True)
# ---> 17     _ = [item for item in executables]
#      18     db.commit()
#      20 print("cool!")
#
# Cell In[1364], line 17, in <listcomp>(.0)
#      15     print('qqq')
#      16     executables = c.execute(sql, multi=True)
# ---> 17     _ = [item for item in executables]
#      18     db.commit()
#      20 print("cool!")
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/cursor.py:457, in MySQLCursor._execute_iter(self, query_iter)
#     455 self._executed = None
#     456 stmt = executed_list.popleft() if executed_list else b"stmt_overflow!"
# --> 457 for result in query_iter:
#     458     self._reset_result()
#     459     self._handle_result(result)
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/connection.py:915, in MySQLConnection.cmd_query_iter(self, statements)
#     913 while self._have_next_result:
#     914     self.handle_unread_result()
# --> 915     yield self._handle_result(self._socket.recv())
#
# File /opt/anaconda3/lib/python3.11/site-packages/mysql/connector/connection.py:635, in MySQLConnection._handle_result(self, packet)
#     633     return self._handle_eof(packet)
#     634 if packet[4] == 255:
# --> 635     raise get_exception(packet)
#     637 # We have a text result set
#     638 column_count = self._protocol.parse_column_count(packet)
#
# IntegrityError: 1062 (23000): Duplicate entry 'OFF-PA-10000477' for key 'products.PRIMARY'

# %% [markdown]
# ### Table: products >

# %% [markdown]
# ### < Table: orders

# %%
def SQL_INSERT_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET):
    sql_texts = []
    for index, row in SOURCE.iterrows():       
        sql_texts.append('INSERT INTO '+TARGET+' ('+ str(', '.join(SOURCE.columns))+ ') VALUES '+ str(tuple(row.values)))        
    return sql_texts

def SQL_CREATE_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET):
    # SQL_CREATE_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET)
    # SOURCE: source dataframe
    # TARGET: target table to be created in database

    sql_text = pd.io.sql.get_schema(SOURCE.reset_index(), TARGET)   
    return sql_text

user = 'root'
password = 'Qwerty123'
host = 'localhost'
database = 'superstore_db'

db = mysql.connector.connect(
    user=user,
    password=password,
    host=host,
    database=database
)

# from sqlalchemy import create_engine
# engine = create_engine(f"mysql://root:Qwerty123@localhost/youtube_db")

insert_statements_list = SQL_INSERT_STATEMENT_FROM_DATAFRAME(df_orders, "orders")
text_query = SQL_CREATE_STATEMENT_FROM_DATAFRAME(df_orders, "orders")

print(text_query)

insert_statements_list_1 = insert_statements_list[:2000:]

my_list = insert_statements_list 

sublists = [my_list[i:i+10] for i in range(0, len(my_list), 10)]


sql = '''
        SET FOREIGN_KEY_CHECKS = 0;
        DROP TABLE IF EXISTS `orders`;
        CREATE TABLE `orders` (
          `order_id` varchar(45) NOT NULL,
          `order_number` varchar(255) DEFAULT NULL,
          `order_date` timestamp DEFAULT NULL,
          `order_priority` varchar(45) DEFAULT NULL,
          `product_id` varchar(45) DEFAULT NULL,
          `quantity` INT DEFAULT NULL,
          `customer_id` varchar(45) DEFAULT NULL,
          `city` varchar(45) DEFAULT NULL,
          `region` varchar(45) DEFAULT NULL,
          `market_id` varchar(45) DEFAULT NULL,
          PRIMARY KEY (`order_id`)
        ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb3;
        ''' + "; ".join(insert_statements_list)


with db.cursor(buffered=True, dictionary=True) as c: 
    executables = c.execute(sql, multi=True)
    _ = [item for item in executables]
    db.commit() 
print("cool!")

# %%
my_list = insert_statements_list 

sublists = [my_list[i:i+1000] for i in range(0, len(my_list), 1000)]

# %%
sublists
# Out:
# [["INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2011-130813_1', 'CA-2011-130813', Timestamp('2011-01-07 00:00:00'), 'High', 'OFF-PA-10002005', 3, 'LS-172304', 'Los Angeles', 'West', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2011-148614_1', 'CA-2011-148614', Timestamp('2011-01-21 00:00:00'), 'Medium', 'OFF-PA-10002893', 2, 'MV-174854', 'Los Angeles', 'West', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2011-118962_1', 'CA-2011-118962', Timestamp('2011-08-05 00:00:00'), 'Medium', 'OFF-PA-10000659', 3, 'CS-121304', 'Los Angeles', 'West', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2011-118962_2', 'CA-2011-118962', Timestamp('2011-08-05 00:00:00'), 'Medium', 'OFF-PA-10001144', 2, 'CS-121304', 'Los Angeles', 'West', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2011-146969_1', 'CA-2011-146969', Timestamp('2011-09-29 00:00:00'), 'High', 'OFF-PA-10002105', 1, 'AP-109154', 'Los Angeles', 'West', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2011-117317_1', 'CA-2011-117317', Timestamp('2011-10-19 00:00:00'), 'Critical', 'OFF-PA-10004519', 3, 'JF-154904', 'Los Angeles', 'West', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2011-125829_1', 'CA-2011-125829', Timestamp('2011-11-04 00:00:00'), 'Medium', 'OFF-PA-10000223', 3, 'WB-218504', 'Los Angeles', 'West', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2011-151295_1', 'CA-2011-151295', Timestamp('2011-11-12 00:00:00'), 'High', 'OFF-PA-10001947', 2, 'JA-159704', 'Los Angeles', 'West', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2011-135090_1', 'CA-2011-135090', Timestamp('2011-11-22 00:00:00'), 'High', 'OFF-PA-10002245', 9, 'SP-209204', 'Los Angeles', 'West', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2011-133830_1', 'CA-2011-133830', Timestamp('2011-12-05 00:00:00'), 'Medium', 'OFF-PA-10001363', 4, 'RL-196154', 'Los Angeles', 'West', 'US-1')"],
#  ["INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2011-113579_1', 'CA-2011-113579', Timestamp('2011-12-13 00:00:00'), 'High', 'OFF-PA-10001457', 6, 'KD-163454', 'Los Angeles', 'West', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2012
SERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2013-166674_1', 'CA-2013-166674', Timestamp('2013-04-02 00:00:00'), 'Critical', 'OFF-AR-10003156', 3, 'RB-193604', 'Auburn', 'East', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2013-166674_2', 'CA-2013-166674', Timestamp('2013-04-02 00:00:00'), 'Critical', 'OFF-AR-10001953', 6, 'RB-193604', 'Auburn', 'East', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2013-166674_3', 'CA-2013-166674', Timestamp('2013-04-02 00:00:00'), 'Critical', 'OFF-AR-10004974', 3, 'RB-193604', 'Auburn', 'East', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2013-166674_4', 'CA-2013-166674', Timestamp('2013-04-02 00:00:00'), 'Critical', 'OFF-AR-10000588', 3, 'RB-193604', 'Auburn', 'East', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2013-166674_5', 'CA-2013-166674', Timestamp('2013-04-02 00:00:00'), 'Critical', 'OFF-ST-10001469', 3, 'RB-193604', 'Auburn', 'East', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2013-101329_1', 'CA-2013-101329', Timestamp('2013-04-23 00:00:00'), 'Medium', 'OFF-AR-10000614', 9, 'MM-179204', 'Rome', 'East', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2013-101329_2', 'CA-2013-101329', Timestamp('2013-04-23 00:00:00'), 'Medium', 'OFF-AR-10003190', 1, 'MM-179204', 'Rome', 'East', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2013-139941_1', 'CA-2013-139941', Timestamp('2013-06-13 00:00:00'), 'Medium', 'OFF-AP-10004036', 3, 'CB-124154', 'Long Beach', 'East', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2013-139941_2', 'CA-2013-139941', Timestamp('2013-06-13 00:00:00'), 'Medium', 'OFF-PA-10000241', 3, 'CB-124154', 'Long Beach', 'East', 'US-1')",
#   "INSERT INTO orders (order_id, order_number, order_date, order_priority, product_id, quantity, customer_id, city, region, market_id) VALUES ('CA-2013-111682_1', 'CA-2013-111682', Timestamp('2013-06-18 00:00:00'), 'Critical', 'OFF-AR-10001868', 1, 'TB-210554', 'Troy', 'East', 'US-1')"]]

# %% [markdown]
# ### Table: orders >

# %% [markdown]
# ### < Table: markets

# %%
def SQL_INSERT_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET):
    sql_texts = []
    for index, row in SOURCE.iterrows():       
        sql_texts.append('INSERT INTO '+TARGET+' ('+ str(', '.join(SOURCE.columns))+ ') VALUES '+ str(tuple(row.values)))        
    return sql_texts

def SQL_CREATE_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET):
    # SQL_CREATE_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET)
    # SOURCE: source dataframe
    # TARGET: target table to be created in database

    sql_text = pd.io.sql.get_schema(SOURCE.reset_index(), TARGET)   
    return sql_text

user = 'root'
password = 'Qwerty123'
host = 'localhost'
database = 'superstore_db'

db = mysql.connector.connect(
    user=user,
    password=password,
    host=host,
    database=database
)

# from sqlalchemy import create_engine
# engine = create_engine(f"mysql://root:Qwerty123@localhost/youtube_db")

insert_statements_list = SQL_INSERT_STATEMENT_FROM_DATAFRAME(df_markets, "markets")
text_query = SQL_CREATE_STATEMENT_FROM_DATAFRAME(df_markets, "markets")

print(text_query)


# sql = '''
#         SET FOREIGN_KEY_CHECKS = 0;
#         DROP TABLE IF EXISTS `markets`;
#         CREATE TABLE `markets` (
#           `market_id` varchar(45) NOT NULL,
#           `market` varchar(255) DEFAULT NULL,
#           `country` varchar(45) DEFAULT NULL,
#           PRIMARY KEY (`market_id`)
#         ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb3;
#         ''' + "; ".join(insert_statements_list)

# with db.cursor(buffered=True, dictionary=True) as c: 
#     executables = c.execute(sql, multi=True)
#     _ = [item for item in executables]
#     db.commit() 
# print("cool!")

# %% [markdown]
# ### Table: markets >

# %% [markdown]
# ### < Table: shipments

# %%
def SQL_INSERT_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET):
    sql_texts = []
    for index, row in SOURCE.iterrows():       
        sql_texts.append('INSERT INTO '+TARGET+' ('+ str(', '.join(SOURCE.columns))+ ') VALUES '+ str(tuple(row.values)))        
    return sql_texts

def SQL_CREATE_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET):
    # SQL_CREATE_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET)
    # SOURCE: source dataframe
    # TARGET: target table to be created in database

    sql_text = pd.io.sql.get_schema(SOURCE.reset_index(), TARGET)   
    return sql_text

user = 'root'
password = 'Qwerty123'
host = 'localhost'
database = 'superstore_db'

db = mysql.connector.connect(
    user=user,
    password=password,
    host=host,
    database=database
)

# from sqlalchemy import create_engine
# engine = create_engine(f"mysql://root:Qwerty123@localhost/youtube_db")

insert_statements_list = SQL_INSERT_STATEMENT_FROM_DATAFRAME(df_shipments, "shipments")
text_query = SQL_CREATE_STATEMENT_FROM_DATAFRAME(df_shipments, "shipments")

print(text_query)


# sql = '''
#         SET FOREIGN_KEY_CHECKS = 0;
#         DROP TABLE IF EXISTS `shipments`;
#         CREATE TABLE `shipments` (
#           `order_id` varchar(45) NOT NULL,
#           `ship_date` 
#           `ship_mode` varchar(255) DEFAULT NULL,
#           `ship_cost` 
#           `state` varchar(255) DEFAULT NULL,
#           PRIMARY KEY (`order_id`)
#         ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb3;
#         ''' + "; ".join(insert_statements_list)

# with db.cursor(buffered=True, dictionary=True) as c: 
#     executables = c.execute(sql, multi=True)
#     _ = [item for item in executables]
#     db.commit() 
# print("cool!")

# %% [markdown]
# ### Table: shipments >

# %% [markdown]
# ### < Table: payments

# %%
def SQL_INSERT_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET):
    sql_texts = []
    for index, row in SOURCE.iterrows():       
        sql_texts.append('INSERT INTO '+TARGET+' ('+ str(', '.join(SOURCE.columns))+ ') VALUES '+ str(tuple(row.values)))        
    return sql_texts

def SQL_CREATE_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET):
    # SQL_CREATE_STATEMENT_FROM_DATAFRAME(SOURCE, TARGET)
    # SOURCE: source dataframe
    # TARGET: target table to be created in database

    sql_text = pd.io.sql.get_schema(SOURCE.reset_index(), TARGET)   
    return sql_text

user = 'root'
password = 'Qwerty123'
host = 'localhost'
database = 'superstore_db'

db = mysql.connector.connect(
    user=user,
    password=password,
    host=host,
    database=database
)

# from sqlalchemy import create_engine
# engine = create_engine(f"mysql://root:Qwerty123@localhost/youtube_db")

insert_statements_list = SQL_INSERT_STATEMENT_FROM_DATAFRAME(df_payments, "payments")
text_query = SQL_CREATE_STATEMENT_FROM_DATAFRAME(df_payments, "payments")

print(text_query)


# sql = '''
#         SET FOREIGN_KEY_CHECKS = 0;
#         DROP TABLE IF EXISTS `payments`;
#         CREATE TABLE `payments` (
#           `order_id` varchar(45) NOT NULL,
#           `sales` 
#           `profit` 
#           `discount` 
#           PRIMARY KEY (`order_id`)
#         ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb3;
#         ''' + "; ".join(insert_statements_list)

# with db.cursor(buffered=True, dictionary=True) as c: 
#     executables = c.execute(sql, multi=True)
#     _ = [item for item in executables]
#     db.commit() 
# print("cool!")

# %% [markdown]
# ### Table: payments >
